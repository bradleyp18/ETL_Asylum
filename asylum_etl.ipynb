# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
#application_file upload will be based on file location on local machine
application_file = r"C:\Users\bradl\Desktop\Git\nwBootCamp\ETL_Asylum\Resources\asylum-applications.csv"
application_df = pd.read_csv(application_file)
application_df.head()
# Out:
#    Year Country of origin Country of origin (ISO) Country of asylum  \
# 0  2006       Afghanistan                     AFG         Australia
# 1  2006           Albania                     ALB         Australia
# 2  2006           Algeria                     DZA         Australia
# 3  2006             Egypt                     EGY         Australia
# 4  2006           Bahrain                     BHR         Australia
#
#   Country of asylum (ISO)  applied
# 0                     AUS       14
# 1                     AUS       21
# 2                     AUS        5
# 3                     AUS       38
# 4                     AUS       11

# %%
decision_file = r"C:\Users\bradl\Desktop\Git\nwBootCamp\ETL_Asylum\Resources\asylum-decisions.csv"
decision_df = pd.read_csv(decision_file)
decision_df.head()
# Out:
#    Year Country of origin Country of origin (ISO) Country of asylum  \
# 0  2000       Afghanistan                     AFG         Australia
# 1  2000           Albania                     ALB         Australia
# 2  2000           Algeria                     DZA         Australia
# 3  2000             Egypt                     EGY         Australia
# 4  2000           Armenia                     ARM         Australia
#
#   Country of asylum (ISO)  Recognized decisions  Complementary protection  \
# 0                     AUS                    38                         0
# 1                     AUS                     5                         0
# 2                     AUS                     5                         0
# 3                     AUS                    20                         0
# 4                     AUS                     0                         0
#
#    Rejected decisions  Otherwise closed  Total decisions
# 0                  25                 0               63
# 1                  23                 0               28
# 2                  15                 0               20
# 3                  49                 5               74
# 4                   5                 0                5

# %% [markdown]
# ### Transform application DataFrame

# %%
application_df.shape
# Out:
# (90803, 6)

# %%
application_df["Country of origin"].value_counts()
# Out:
# Iraq                      1945
# Dem. Rep. of the Congo    1932
# Somalia                   1863
# Afghanistan               1846
# Iran (Islamic Rep. of)    1789
#                           ...
# Gibraltar                    1
# Cook Islands                 1
# Anguilla                     1
# Marshall Islands             1
# Puerto Rico                  1
# Name: Country of origin, Length: 212, dtype: int64

# %%
new_application_df = application_df[['Year', 'Country of origin', 'Country of asylum', 'applied']].copy()

new_application_transformed_df = new_application_df.rename(columns={"Year": "year",
                                                          "Country of origin": "country_of_origin",
                                                          "Country of asylum": "country_of_asylum",
                                                          "applied": "applied"
                                                         })
new_application_transformed_df.head()
# Out:
#    year country_of_origin country_of_asylum  applied
# 0  2006       Afghanistan         Australia       14
# 1  2006           Albania         Australia       21
# 2  2006           Algeria         Australia        5
# 3  2006             Egypt         Australia       38
# 4  2006           Bahrain         Australia       11

# %%
us_application_df = new_application_transformed_df.loc[new_application_transformed_df["country_of_asylum"] == "United States of America"]

us_application_df.reset_index(drop=True)
# Out:
#       year country_of_origin         country_of_asylum  applied
# 0     2017           Albania  United States of America        5
# 1     2017             Egypt  United States of America       29
# 2     2017         Argentina  United States of America        5
# 3     2017        Bangladesh  United States of America        5
# 4     2017            Brazil  United States of America       52
# ...    ...               ...                       ...      ...
# 5985  2005             Yemen  United States of America       13
# 5986  2005            Zambia  United States of America       16
# 5987  2005          Zimbabwe  United States of America      222
# 5988  2005         Stateless  United States of America       83
# 5989  2005          Unknown   United States of America      260
#
# [5990 rows x 4 columns]

# %%
us_application_df["country_of_origin"].value_counts()
# Out:
# Albania             46
# India               46
# Indonesia           46
# Jordan              46
# Syrian Arab Rep.    46
#                     ..
# Iceland              1
# Samoa                1
# Curacao              1
# Cayman Islands       1
# Marshall Islands     1
# Name: country_of_origin, Length: 191, dtype: int64

# %%
us_application_df_merge = us_application_df
us_application_df_merge['merge_key'] = us_application_df['year'].astype(str) + us_application_df['country_of_origin']+us_application_df['country_of_asylum']
us_application_df_merge
# Out:
# <ipython-input-54-8aa219dc1612>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_application_df_merge['merge_key'] = us_application_df['year'].astype(str) + us_application_df['country_of_origin']+us_application_df['country_of_asylum']
#        year country_of_origin         country_of_asylum  applied  \
# 6112   2017           Albania  United States of America        5
# 6113   2017             Egypt  United States of America       29
# 6114   2017         Argentina  United States of America        5
# 6115   2017        Bangladesh  United States of America        5
# 6116   2017            Brazil  United States of America       52
# ...     ...               ...                       ...      ...
# 77155  2005             Yemen  United States of America       13
# 77156  2005            Zambia  United States of America       16
# 77157  2005          Zimbabwe  United States of America      222
# 77158  2005         Stateless  United States of America       83
# 77159  2005          Unknown   United States of America      260
#
#                                     merge_key
# 6112      2017AlbaniaUnited States of America
# 6113        2017EgyptUnited States of America
# 6114    2017ArgentinaUnited States of America
# 6115   2017BangladeshUnited States of America
# 6116       2017BrazilUnited States of America
# ...                                       ...
# 77155       2005YemenUnited States of America
# 77156      2005ZambiaUnited States of America
# 77157    2005ZimbabweUnited States of America
# 77158   2005StatelessUnited States of America
# 77159    2005Unknown United States of America
#
# [5990 rows x 5 columns]

# %% [markdown]
# ### Transform decision DataFrame

# %%
decision_df.shape
# Out:
# (82518, 10)

# %%
decision_df["Country of asylum"].value_counts()
# Out:
# United States of America                                5767
# Sweden                                                  4207
# Germany                                                 4065
# France                                                  3459
# United Kingdom of Great Britain and Northern Ireland    3451
#                                                         ...
# Vanuatu                                                    1
# Samoa                                                      1
# Grenada                                                    1
# Viet Nam                                                   1
# Lao People's Dem. Rep.                                     1
# Name: Country of asylum, Length: 183, dtype: int64

# %%
new_decision_df = decision_df[['Year', 'Country of origin', 'Country of asylum', 'Recognized decisions', 'Complementary protection','Rejected decisions','Otherwise closed','Total decisions']].copy()
new_decision_transformed_df = new_decision_df.rename(columns={"Year": "year",
                                                          "Country of origin": "country_of_origin",
                                                          "Country of asylum": "country_of_asylum",
                                                          "Recognized decisions": "recognized_decisions",
                                                          "Complementary protection": "complementary_protection",
                                                          "Rejected decisions": "rejected_decisions",
                                                          "Otherwise closed": "otherwise_closed",
                                                          "Total decisions": "total_decisions"
                                                         })

new_decision_transformed_df.head()
# Out:
#    year country_of_origin country_of_asylum  recognized_decisions  \
# 0  2000       Afghanistan         Australia                    38
# 1  2000           Albania         Australia                     5
# 2  2000           Algeria         Australia                     5
# 3  2000             Egypt         Australia                    20
# 4  2000           Armenia         Australia                     0
#
#    complementary_protection  rejected_decisions  otherwise_closed  \
# 0                         0                  25                 0
# 1                         0                  23                 0
# 2                         0                  15                 0
# 3                         0                  49                 5
# 4                         0                   5                 0
#
#    total_decisions
# 0               63
# 1               28
# 2               20
# 3               74
# 4                5

# %%
us_decision_df = new_decision_transformed_df.loc[new_decision_transformed_df["country_of_asylum"] == "United States of America"]

us_decision_df.reset_index(drop=True)
# Out:
#       year                   country_of_origin         country_of_asylum  \
# 0     2017                         Afghanistan  United States of America
# 1     2017                             Albania  United States of America
# 2     2017                              Angola  United States of America
# 3     2017                               Egypt  United States of America
# 4     2017                             Armenia  United States of America
# ...    ...                                 ...                       ...
# 5762  2020  Venezuela (Bolivarian Republic of)  United States of America
# 5763  2020                               Yemen  United States of America
# 5764  2020                              Zambia  United States of America
# 5765  2020                            Zimbabwe  United States of America
# 5766  2020                            Unknown   United States of America
#
#       recognized_decisions  complementary_protection  rejected_decisions  \
# 0                        5                         0                   0
# 1                       38                         0                   0
# 2                        5                         0                   0
# 3                      104                         0                   5
# 4                       15                         0                   5
# ...                    ...                       ...                 ...
# 5762                  1356                         0                3118
# 5763                    23                         0                  42
# 5764                     5                         0                   5
# 5765                    27                         0                  35
# 5766                    39                         0                  95
#
#       otherwise_closed  total_decisions
# 0                    5               10
# 1                   19               57
# 2                    0                5
# 3                   58              167
# 4                   18               38
# ...                ...              ...
# 5762              1157             5631
# 5763                42              107
# 5764                 0               10
# 5765                23               85
# 5766                51              185
#
# [5767 rows x 8 columns]

# %%
us_decision_df["country_of_origin"].value_counts()
# Out:
# Guatemala                 46
# Dem. Rep. of the Congo    46
# Cameroon                  46
# Nicaragua                 46
# Uzbekistan                46
#                           ..
# Cayman Islands             1
# Marshall Islands           1
# Norway                     1
# Cyprus                     1
# Botswana                   1
# Name: country_of_origin, Length: 184, dtype: int64

# %%
us_decision_df_merge = us_decision_df
us_decision_df_merge ['merge_key'] = us_decision_df['year'].astype(str) + us_decision_df['country_of_origin']+us_decision_df['country_of_asylum']
us_decision_df_merge.sort(['year'], descending = True)
# Out:
# <ipython-input-70-43b8c174f9eb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_decision_df_merge ['merge_key'] = us_decision_df['year'].astype(str) + us_decision_df['country_of_origin']+us_decision_df['country_of_asylum']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-43b8c174f9eb> in <module>
#       1 us_decision_df_merge = us_decision_df
#       2 us_decision_df_merge ['merge_key'] = us_decision_df['year'].astype(str) + us_decision_df['country_of_origin']+us_decision_df['country_of_asylum']
# ----> 3 us_decision_df_merge.sort(['year'], descending = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# ### Merge Application and Decision DataFrames

# %%
# Still needs some edits
merged_df = pd.merge(us_application_df_merge,us_decision_df_merge, how='inner')
merged_df
# Out:
#        year country_of_origin         country_of_asylum  applied  \
# 0      2017           Albania  United States of America        5
# 1      2017           Albania  United States of America        5
# 2      2017           Albania  United States of America        5
# 3      2017           Albania  United States of America      181
# 4      2017           Albania  United States of America      181
# ...     ...               ...                       ...      ...
# 11673  2005      Turkmenistan  United States of America       59
# 11674  2005            Zambia  United States of America       16
# 11675  2005            Zambia  United States of America       16
# 11676  2005          Unknown   United States of America      260
# 11677  2005          Unknown   United States of America      260
#
#                                       merge_key  recognized_decisions  \
# 0           2017AlbaniaUnited States of America                    38
# 1           2017AlbaniaUnited States of America                    88
# 2           2017AlbaniaUnited States of America                    13
# 3           2017AlbaniaUnited States of America                    38
# 4           2017AlbaniaUnited States of America                    88
# ...                                         ...                   ...
# 11673  2005TurkmenistanUnited States of America                    20
# 11674        2005ZambiaUnited States of America                    10
# 11675        2005ZambiaUnited States of America                     5
# 11676      2005Unknown United States of America                     5
# 11677      2005Unknown United States of America                     0
#
#        complementary_protection  rejected_decisions  otherwise_closed  \
# 0                             0                   0                19
# 1                             0                  37                35
# 2                             0                  56                64
# 3                             0                   0                19
# 4                             0                  37                35
# ...                         ...                 ...               ...
# 11673                         0                  28                 5
# 11674                         0                  10                10
# 11675                         0                  12                 5
# 11676                         0                  17                 0
# 11677                         0                 300                10
#
#        total_decisions
# 0                   57
# 1                  160
# 2                  133
# 3                   57
# 4                  160
# ...                ...
# 11673               53
# 11674               30
# 11675               22
# 11676               22
# 11677              310
#
# [11678 rows x 10 columns]

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/asylum_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# <ipython-input-34-2d97e9123e98>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-34-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# <string> in table_names(self, schema, connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    3109         :param connection: Optional, use a specified connection.
#    3110         """
# -> 3111         with self._optional_conn_ctx_manager(connection) as conn:
#    3112             insp = inspection.inspect(conn)
#    3113             return insp.get_table_names(schema)
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2857     def _optional_conn_ctx_manager(self, connection=None):
#    2858         if connection is None:
# -> 2859             with self.connect() as conn:
#    2860                 yield conn
#    2861         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
# -> 3144                 Connection._handle_dbapi_exception_noconnection(
#    3145                     e, dialect, self
#    3146                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Load DataFrames into database

# %%
us_application_df.to_sql(name='application', con=engine, if_exists='append', index=True)

# %%
us_decision_df.to_sql(name='decision', con=engine, if_exists='append', index=True)
